# %%
# Imports
import os
from os.path import join as join_path
import numpy as np
rng_seed = 399
np.random.seed(rng_seed)
import pickle
import pandas as pd
from tqdm.auto import tqdm

import tensorflow as tf
tf.random.set_seed(rng_seed)
from tensorflow.keras import Model
from tensorflow.keras.preprocessing.sequence import skipgrams, make_sampling_table
from tensorflow.keras.utils import plot_model, to_categorical, Progbar
from tensorflow.keras.preprocessing.text import Tokenizer, tokenizer_from_json

from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Dense, Reshape, dot, Embedding, Dot
from tensorflow.keras.optimizers import Adam

from models import build_word2vec_model_dense

# %%
# Define constants
# ----------------
data_dir = 'data'
checkpoints_dir = 'checkpoints'
text8_data_tokenizer_config_path = join_path(data_dir, 'text8-tokenizer.json')
text8_data_sequences_path = join_path(data_dir, 'text8-seqs.p')
os.makedirs(checkpoints_dir, exist_ok=True)

sampling_window_size = 5
num_negative_samples = 5
embedding_dim = 300

# Training constants
epochs = 15
batch_size = 64
# ----------------

# %% [markdown]
# # Load data

# %%
# Load text8 data sequences from data preprocessing
with open(text8_data_sequences_path, 'rb') as file:
    text8_seqs = pickle.load(file)

# %%
# Read tokenizer from file
with open(text8_data_tokenizer_config_path, 'r') as file:
    tokenizer = tokenizer_from_json(file.read())
vocab_size = len(tokenizer.word_index)

# %% [markdown]
# ## Create Word2vec model

# %%
def build_word2vec_model(vocab_size: int, vector_dim: int):
    '''
    TODO: Docs
    '''
    # Input to network
    input_shape = (vocab_size + 1,)
    input_target = Input(input_shape, name='input_target')
    input_context = Input(input_shape, name='input_context')

    # Embedding layer using Dense layers
    target_embedding = Dense(vector_dim, input_shape=input_shape, name='target_embedding')(input_target)
    context_embedding = Dense(vector_dim, input_shape=input_shape, name='context_embedding')(input_context)
    
    # Compute (unnormalized) cosine similarity
    dot_product = Dot(axes=1, name='dot_product')([target_embedding, context_embedding])
    
    # Sigmoid activation (output)
    output = Dense(1, activation='sigmoid', name='sigmoid_activation')(dot_product)
    
    # Create model
    model = Model(inputs=[input_target, input_context], outputs=output)
    adam = Adam(learning_rate=0.001)
    model.compile(loss='binary_crossentropy', optimizer=adam)
    
    return model

# %%
# Create word2vec model
model = build_word2vec_model(vocab_size, embedding_dim)
plot_model(model, show_shapes=True, to_file='word2vec_model.png')

# %%
model.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_target (InputLayer)       [(None, 203432)]     0
# __________________________________________________________________________________________________
# input_context (InputLayer)      [(None, 203432)]     0
# __________________________________________________________________________________________________
# target_embedding (Dense)        (None, 300)          61029900    input_target[0][0]
# __________________________________________________________________________________________________
# context_embedding (Dense)       (None, 300)          61029900    input_context[0][0]
# __________________________________________________________________________________________________
# dot_product (Dot)               (None, 1)            0           target_embedding[0][0]
#                                                                  context_embedding[0][0]
# __________________________________________________________________________________________________
# sigmoid_activation (Dense)      (None, 1)            2           dot_product[0][0]
# ==================================================================================================
# Total params: 122,059,802
# Trainable params: 122,059,802
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Fit Word2vec model

# %%
# TODO: Compare to https://markroxor.github.io/gensim/static/notebooks/Word2Vec_FastText_Comparison.html
# TODO: Explore Gensim? https://radimrehurek.com/gensim/auto_examples/index.html
def fit_model(model: Model,
              tokenizer: Tokenizer,
              text_seqs: list,
              epochs: int,
              batch_size: int,
              vocab_size: int,
              sampling_window_size: int,
              num_negative_samples: int,
              sampling_factor: float = 1e-03,
              skipgram_subsample_size: int = 100,
              checkpoints_dir: str = None):
    '''
    TODO: Docs
    '''
    sampling_table = make_sampling_table(vocab_size + 1, sampling_factor=sampling_factor)
    train_losses = list()
    for epoch in range(1, epochs + 1):
        print(f'-- Epoch #{epoch} --')

        progbar = Progbar(len(text_seqs))
        progbar.update(0)
        
        # Training
        for i, train_text_seq in enumerate(text_seqs):
            
            # Create skipgram pairs
            data_pairs, data_labels = skipgrams(
                train_text_seq,
                vocab_size,
                sampling_table=sampling_table,
                window_size=sampling_window_size,
                negative_samples=num_negative_samples
            )
            data_pairs = np.array(data_pairs)
            data_labels = np.array(data_labels).reshape(-1, 1)
            
            # Sample from skipgram pairs
            subsample_indices = np.random.choice(
                len(data_pairs),
                replace=False,
                size=np.minimum(len(data_pairs), skipgram_subsample_size)
            )
            data_pairs = data_pairs[subsample_indices]
            data_labels = data_labels[subsample_indices]

            num_skipgram_pairs = len(data_pairs)
            indices = np.arange(num_skipgram_pairs, dtype=int)
            np.random.shuffle(indices)

            # Train model in batches of skipgram pairs
            num_batches = int(np.ceil(num_skipgram_pairs / batch_size))
            for batch_nr in range(num_batches):
                indices_batch = indices[batch_nr * batch_size:(batch_nr + 1) * batch_size]

                batch_pairs = list(to_categorical(data_pairs[indices_batch].T, num_classes=vocab_size + 1))
                batch_labels = data_labels[indices_batch]

                train_loss = model.train_on_batch(batch_pairs, batch_labels)
                progbar.update(i + 1, values=[('train_loss', sum(train_loss))])

        # Save model to file
        if not checkpoints_dir is None:
            # TODO: Save train_loss to file after each epoch
            
            model_checkpoint_path = join_path(checkpoints_dir, f'word2vec-model-epoch-{epoch}.model')
            print(f'Saving model to {model_checkpoint_path}...')
            model.save(model_checkpoint_path)
            print('Done!')

# %%
train_model = True
if train_model:
    fit_model(
        model,
        tokenizer,
        text8_seqs,
        epochs,
        batch_size,
        vocab_size,
        sampling_window_size,
        num_negative_samples,
        checkpoints_dir=checkpoints_dir
    )
# Out:
# -- Epoch #1 --
#     45/504749 [..............................] - ETA: 115:06:46 - train_loss: 1.3728
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-2c49060b0ef4> in <module>
#      10         sampling_window_size,
#      11         num_negative_samples,
# ---> 12         checkpoints_dir=checkpoints_dir
#      13     )
#
# <ipython-input-20-8ae3219a0ffd> in fit_model(model, tokenizer, text_seqs, epochs, batch_size, vocab_size, sampling_window_size, num_negative_samples, sampling_factor, skipgram_subsample_size, checkpoints_dir)
#      58                 batch_labels = data_labels[indices_batch]
#      59
# ---> 60                 train_loss = model.train_on_batch(batch_pairs, batch_labels)
#      61                 progbar.update(i + 1, values=[('train_loss', sum(train_loss))])
#      62
#
# ~/.local/share/virtualenvs/code-gd-a4ILK/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics, return_dict)
#    1344       iterator = data_adapter.single_batch_iterator(self.distribute_strategy, x,
#    1345                                                     y, sample_weight,
# -> 1346                                                     class_weight)
#    1347       train_function = self.make_train_function()
#    1348       logs = train_function(iterator)
#
# ~/.local/share/virtualenvs/code-gd-a4ILK/lib/python3.7/site-packages/tensorflow/python/keras/engine/data_adapter.py in single_batch_iterator(strategy, x, y, sample_weight, class_weight)
#    1385     dataset = dataset.map(_make_class_weight_map_fn(class_weight))
#    1386   dataset = strategy.experimental_distribute_dataset(dataset)
# -> 1387   return iter(dataset)
#    1388
#    1389
#
# ~/.local/share/virtualenvs/code-gd-a4ILK/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     402     """
#     403     if context.executing_eagerly() or ops.inside_function():
# --> 404       return iterator_ops.OwnedIterator(self)
#     405     else:
#     406       raise RuntimeError("__iter__() is only supported inside of tf.function "
#
# ~/.local/share/virtualenvs/code-gd-a4ILK/lib/python3.7/site-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec)
#     593           context.context().device_spec.device_type != "CPU"):
#     594         with ops.device("/cpu:0"):
# --> 595           self._create_iterator(dataset)
#     596       else:
#     597         self._create_iterator(dataset)
#
# ~/.local/share/virtualenvs/code-gd-a4ILK/lib/python3.7/site-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     599   def _create_iterator(self, dataset):
#     600     # pylint: disable=protected-access
# --> 601     dataset = dataset._apply_options()
#     602
#     603     # Store dataset reference to ensure that dataset is alive when this iterator
#
# ~/.local/share/virtualenvs/code-gd-a4ILK/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py in _apply_options(self)
#     373       else:
#     374         dataset = _OptimizeDataset(dataset, graph_rewrites,
# --> 375                                    graph_rewrite_configs)
#     376
#     377     # (3) Apply autotune options
#
# ~/.local/share/virtualenvs/code-gd-a4ILK/lib/python3.7/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, input_dataset, optimizations, optimization_configs)
#    4363         self._optimizations,
#    4364         optimization_configs=optimization_configs,
# -> 4365         **self._flat_structure)
#    4366     super(_OptimizeDataset, self).__init__(input_dataset, variant_tensor)
#    4367
#
# ~/.local/share/virtualenvs/code-gd-a4ILK/lib/python3.7/site-packages/tensorflow/python/ops/gen_dataset_ops.py in optimize_dataset(input_dataset, optimizations, output_types, output_shapes, optimization_configs, name)
#    3677         tld.op_callbacks, input_dataset, optimizations, "output_types",
#    3678         output_types, "output_shapes", output_shapes, "optimization_configs",
# -> 3679         optimization_configs)
#    3680       return _result
#    3681     except _core._FallbackException:
#
# KeyboardInterrupt:

# %%
np.random.choice(np.arange(9), replace=False, size=10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-fe7263786eec> in <module>
# ----> 1 np.random.choice(np.arange(9), replace=False, size=10)
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'
